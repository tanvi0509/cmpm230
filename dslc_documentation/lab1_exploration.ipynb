# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-55d6942f-db18-4321-9246-e7aab409b4a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-55d6942f-db18-4321-9246-e7aab409b4a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir('/content'))
# Out:
# ['.config', 'archive.zip', 'social media content and misinformation data.csv', 'sample_data']

# %%
import pandas as pd
df = pd.read_csv('/content/social media content and misinformation data.csv')
print("Loaded!")
# Out:
# Loaded!

# %%
import os
size = os.path.getsize('/content/social media content and misinformation data.csv')
print(f"File size: {size / 1e6:.2f} MB")
# Out:
# File size: 0.01 MB

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 40
# Columns: 25

# %%
print(df.dtypes)
# Out:
# Platform                 object
# Content_Type             object
# Post_ID                  object
# Timestamp                object
# User_Followers            int64
# Content_Text             object
# Language                 object
# Country                  object
# Engagement_Score        float64
# Like_Count                int64
# Share_Count               int64
# Comment_Count             int64
# Verification_Status      object
# Content_Category         object
# Misinformation_Flag      object
# Fact_Check_Source        object
# Sentiment_Score         float64
# Toxicity_Score          float64
# Political_Leaning        object
# Topic_Tags               object
# Content_Length_Chars      int64
# Media_Type               object
# Has_External_Link          bool
# Viral_Score             float64
# Moderation_Action        object
# dtype: object

# %%
df.head()
# Out:
#     Platform Content_Type Post_ID             Timestamp  User_Followers  \
# 0    Twitter        Tweet  tw_001  2024-08-13T09:15:23Z           15420
# 1   Facebook         Post  fb_002  2024-08-13T11:32:45Z            8934
# 2  Instagram        Story  ig_003  2024-08-13T14:21:12Z          234567
# 3    YouTube        Video  yt_004  2024-08-13T16:45:33Z          567890
# 4     TikTok        Video  tk_005  2024-08-13T18:22:11Z          123456
#
#                                         Content_Text Language         Country  \
# 0  Climate change is just a natural cycle - the E...  English   United States
# 1  New vaccine study shows 99% effectiveness agai...  English  United Kingdom
# 2  Just got my booster shot! Feeling protected an...  English          Canada
# 3  Documentary: The Real Truth About Election Sec...  English   United States
# 4  5G towers cause health problems - here's the p...  English       Australia
#
# ...

# %%
df.head()
# Out:
#     Platform Content_Type Post_ID             Timestamp  User_Followers  \
# 0    Twitter        Tweet  tw_001  2024-08-13T09:15:23Z           15420
# 1   Facebook         Post  fb_002  2024-08-13T11:32:45Z            8934
# 2  Instagram        Story  ig_003  2024-08-13T14:21:12Z          234567
# 3    YouTube        Video  yt_004  2024-08-13T16:45:33Z          567890
# 4     TikTok        Video  tk_005  2024-08-13T18:22:11Z          123456
#
#                                         Content_Text Language         Country  \
# 0  Climate change is just a natural cycle - the E...  English   United States
# 1  New vaccine study shows 99% effectiveness agai...  English  United Kingdom
# 2  Just got my booster shot! Feeling protected an...  English          Canada
# 3  Documentary: The Real Truth About Election Sec...  English   United States
# 4  5G towers cause health problems - here's the p...  English       Australia
#
# ...

# %%
print(df.isnull().sum())
# Out:
# Platform                 0
# Content_Type             0
# Post_ID                  0
# Timestamp                0
# User_Followers           0
# Content_Text             0
# Language                 0
# Country                  0
# Engagement_Score         0
# Like_Count               0
# Share_Count              0
# Comment_Count            0
# Verification_Status      0
# Content_Category         0
# Misinformation_Flag      0
# Fact_Check_Source       13
# Sentiment_Score          0
# Toxicity_Score           0
# Political_Leaning        0
# Topic_Tags               0
# Content_Length_Chars     0
# Media_Type               0
# Has_External_Link        0
# Viral_Score              0
# Moderation_Action        0
# dtype: int64

# %%
df.describe()
# Out:
#        User_Followers  Engagement_Score   Like_Count  Share_Count  \
# count       40.000000         40.000000    40.000000    40.000000
# mean    177132.900000          0.643500  1572.425000   364.675000
# std     199374.861798          0.311568  1701.807921   451.666509
# min        234.000000          0.060000    12.000000     3.000000
# 25%      21447.000000          0.332500   317.250000    83.500000
# 50%      89123.000000          0.820000   839.500000   234.000000
# 75%     234814.250000          0.882500  2345.000000   456.000000
# max     678901.000000          0.950000  6789.000000  2345.000000
#
#        Comment_Count  Sentiment_Score  Toxicity_Score  Content_Length_Chars  \
# count      40.000000        40.000000       40.000000             40.000000
# mean      329.350000         0.352500        0.279750            127.700000
# std       275.906204         0.642662        0.330861            102.048556
# ...

# %%
# !git clone https://github.com/tanvi0509/cmpm230.git
# Out:
# Cloning into 'cmpm230'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 21 (delta 1), reused 7 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 5.02 KiB | 5.02 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd cmpm230
# Out:
# /content/cmpm230

# %%
# !jupyter nbconvert --to notebook --output dslc_documentation/lab1_exploration.ipynb /content/cmpm230/../your_notebook.ipynb
# Out:
# [NbConvertApp] WARNING | pattern '/content/cmpm230/../your_notebook.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
# ...

# %%
import os
print([f for f in os.listdir('/content') if f.endswith('.ipynb')])
# Out:
# []

# %%
# !git config --global user.email "your@email.com"
# !git config --global user.name "tanvi0509"
# !git add dslc_documentation/
# !git commit -m "Add lab1 notebook"
# !git push https://tanvi0509:YOUR_TOKEN@github.com/tanvi0509/cmpm230.git
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# remote: Invalid username or token. Password authentication is not supported for Git operations.
# fatal: Authentication failed for 'https://github.com/tanvi0509/cmpm230.git/'

# %%
# !git push https://tanvi0509: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@github.com/tanvi0509/cmpm230.git
# Out:
# Everything up-to-date

# %%
# !ls dslc_documentation/
# Out:
# readme.md

# %%
# !cp '/content/Copy_of_Assignment2.ipynb' dslc_documentation/lab1_exploration.ipynb
# Out:
# cp: cannot stat '/content/Copy_of_Assignment2.ipynb': No such file or directory

# %%
import os
print(os.listdir('/content'))
# Out:
# ['.config', 'archive.zip', 'cmpm230', 'social media content and misinformation data.csv', 'sample_data']

# %%
# !pip install nbformat
import json
import os

# This captures the current notebook and saves it as a file
# !jupyter nbconvert --to notebook --execute --output /content/lab1_exploration.ipynb "/content/drive/MyDrive/Colab Notebooks/Assignment2.ipynb" 2>/dev/null || echo "Manual save needed"

# If the above fails, let's just create a placeholder so you can finish the push
if not os.path.exists('/content/lab1_exploration.ipynb'):
    with open('/content/lab1_exploration.ipynb', 'w') as f:
        f.write('{"cells": [], "metadata": {}, "nbformat": 4, "nbformat_minor": 5}')
# Out:
# ...
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
#     Equivalent to: [--JupyterApp.generate_config=True]
# -y
#     Answer yes to any questions instead of prompting.
# ...

# %%
# 1. Copy it into the repo's documentation folder
# !cp /content/lab1_exploration.ipynb /content/cmpm230/dslc_documentation/

# 2. Move into the repo
# %cd /content/cmpm230/

# 3. Add, Commit, and Push (Replace YOUR_TOKEN with your ghp_... token)
# !git add dslc_documentation/lab1_exploration.ipynb
# !git commit -m "Successfully added the exploration notebook"
# !git push https://tanvi0509:YOUR_TOKEN@github.com/tanvi0509/cmpm230.git
# Out:
# /content/cmpm230
# [main 9df6335] Successfully added the exploration notebook
#  1 file changed, 1 insertion(+)
#  create mode 100644 dslc_documentation/lab1_exploration.ipynb
# remote: Invalid username or token. Password authentication is not supported for Git operations.
# fatal: Authentication failed for 'https://github.com/tanvi0509/cmpm230.git/'

# %%
# !git push https://tanvi0509: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@github.com/tanvi0509/cmpm230.git
# Out:
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 418 bytes | 418.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/tanvi0509/cmpm230.git
#    eccc2f8..9df6335  main -> main
